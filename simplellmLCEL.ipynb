# %%
##  open Source models - Llama3 , Gemma2 ,mistral--Groq
import os
from dotenv  import load_dotenv

load_dotenv()
import openai
openai.api_key = os.getenv("OPENAI_API_KEY")
groq_api_key = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq     
ChatGroq( model_name="gemma2-9b-it",groq_api_key=groq_api_key)
## update api key
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x000001BE3D3A2840>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001BE3D3A3770>, model_name='gemma2-9b-it', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain_groq import ChatGroq
model=ChatGroq(model="Gemma2-9b-It",groq_api_key=groq_api_key)
model
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x000001BE3E5734A0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001BE3E573050>, model_name='Gemma2-9b-It', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[17], line 8
#       1 from langchain_core.messages import HumanMessage,SystemMessage
#       3 messages=[
#       4     SystemMessage(content="Translate the following from English to French"),
#       5     HumanMessage(content="Hello How are you?")
#       6 ]
# ----> 8 result=model.invoke(messages)
#
# File c:\Users\gokul_das\Documents\AI course Udemy\genAiLearn\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:331, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     319 @override
#     320 def invoke(
#     321     self,
#    (...)    326     **kwargs: Any,
#     327 ) -> BaseMessage:
#     328     config = ensure_config(config)
#     329     return cast(
#     330         "ChatGeneration",
# --> 331         self.generate_prompt(
#     332             [self._convert_input(input)],
# ...

# %%
from langchain_core.messages import HumanMessage, SystemMessage

# Ensure that the content is properly formatted
messages = [
    SystemMessage(content="Reply to the question"),
    HumanMessage(content="Hello, how are you?")  # Use standard quotes
]

result = model.invoke(messages)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[22], line 9
#       3 # Ensure that the content is properly formatted
#       4 messages = [
#       5     SystemMessage(content="Reply to the question"),
#       6     HumanMessage(content="Hello, how are you?")  # Use standard quotes
#       7 ]
# ----> 9 result = model.invoke(messages).encode("UTF-16")
#
# File c:\Users\gokul_das\Documents\AI course Udemy\genAiLearn\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:331, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     319 @override
#     320 def invoke(
#     321     self,
#    (...)    326     **kwargs: Any,
#     327 ) -> BaseMessage:
#     328     config = ensure_config(config)
#     329     return cast(
#     330         "ChatGeneration",
# --> 331         self.generate_prompt(
# ...
